# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img= Image.open(r"C:\Users\saransh\OneDrive\Desktop\New folder (2)\pexels-optical-chemist-340351297-31256342.jpg")


img= np.array(img)

img[:, :, 0] = np.clip(img[:, :, 0] + 90, 100, 255)

plt.imshow(img)
plt.axis("off")
plt.show()
